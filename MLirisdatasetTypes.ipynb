# %% [markdown]
# 35.	The Iris data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.
#
# i.	Understand the Dataset & cleanup (if required).
#
# ii.	Build a decision tree classifier to predict the iris plant category? (Use GINI INDEX criteria, use max_depth=4, min_samples_split=2)
#
# iii.	Evaluate the model using Accuracy.

# %%
# Importing the required libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import plot_tree

# Load the Iris dataset
file_path = 'Iris.csv'  # Path to the uploaded Iris dataset
df = pd.read_csv(file_path)

# Step 1: Understand and clean the dataset (no cleanup required here)
print("Dataset Overview:")
print(df.head())  # Display first few rows

# Step 2: Convert the categorical 'Species' column to numerical labels
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])  # Encode species

# Step 3: Split the dataset into features and target variable
X = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = df['Species']

# Step 4: Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 5: Standardize the feature data (optional for decision trees but good practice)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Step 6: Train Decision Tree Classifier using Gini Index
clf_gini = DecisionTreeClassifier(criterion="gini", max_depth=4, min_samples_split=2, random_state=42)
clf_gini.fit(X_train, y_train)

# Step 7: Make predictions
y_pred_gini = clf_gini.predict(X_test)

# Step 8: Evaluate the model using accuracy
def evaluate_model(y_test, y_pred):
    accuracy = accuracy_score(y_test, y_pred)
    print(f"\nAccuracy: {accuracy * 100:.2f}%")

    # Display the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    print("\nConfusion Matrix:\n", cm)

    # Print classification report
    class_report = classification_report(y_test, y_pred)
    print("\nClassification Report:\n", class_report)

    return accuracy

accuracy_gini = evaluate_model(y_test, y_pred_gini)

# Step 9: Plot the decision tree
def plot_decision_tree(clf, feature_names, class_names):
    plt.figure(figsize=(15, 10))
    plot_tree(clf, filled=True, feature_names=feature_names, class_names=class_names, rounded=True)
    plt.show()

plot_decision_tree(clf_gini, X.columns, le.classes_)
# Out:
# Dataset Overview:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# Accuracy: 100.00%
#
# Confusion Matrix:
#  [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# ...

# %% [markdown]
# 36.	The Iris data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.
#
# i.	Understand the Dataset & cleanup (if required).
#
# ii.	Build a decision tree classifier to predict the iris plant category? (Use Entropy criteria, use max_depth=4, min_samples_split=2)
#
# iii.	Evaluate the model using Accuracy.

# %%
# Importing the required libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Load the Iris dataset
file_path = 'Iris.csv'  # Path to the uploaded Iris dataset
df = pd.read_csv(file_path)

# Step 1: Understand and clean the dataset (no cleanup required here)
print("Dataset Overview:")
print(df.head())  # Display first few rows

# Step 2: Convert the categorical 'Species' column to numerical labels
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])  # Encode species

# Step 3: Split the dataset into features and target variable
X = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = df['Species']

# Step 4: Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 5: Standardize the feature data (optional for decision trees but good practice)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Step 6: Train Decision Tree Classifier using Entropy
clf_entropy = DecisionTreeClassifier(criterion="entropy", max_depth=4, min_samples_split=2, random_state=42)
clf_entropy.fit(X_train, y_train)

# Step 7: Make predictions
y_pred_entropy = clf_entropy.predict(X_test)

# Step 8: Evaluate the model using accuracy
def evaluate_model(y_test, y_pred):
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy: {accuracy * 100:.2f}%")

    # Display the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    print("\nConfusion Matrix:\n", cm)

    # Print classification report
    class_report = classification_report(y_test, y_pred)
    print("\nClassification Report:\n", class_report)

    return accuracy

accuracy_entropy = evaluate_model(y_test, y_pred_entropy)

# Step 9: Plot the decision tree
def plot_decision_tree(clf, feature_names, class_names):
    plt.figure(figsize=(15, 10))
    plot_tree(clf, filled=True, feature_names=feature_names, class_names=class_names, rounded=True)
    plt.show()

plot_decision_tree(clf_entropy, X.columns, le.classes_)
# Out:
# Dataset Overview:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# Accuracy: 100.00%
#
# Confusion Matrix:
#  [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# ...

# %% [markdown]
# 37.	The Iris data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.
#
# i.	Understand the Dataset & cleanup (if required).
#
# ii.	Build a decision tree classifier to predict the iris plant category? (Use log loss criteria, use max_depth=4, min_samples_split=2)
#
# iii.	Evaluate the model using Accuracy.

# %%
# Importing the required libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Load the Iris dataset
file_path = 'Iris.csv'  # Path to the uploaded Iris dataset
df = pd.read_csv(file_path)

# Step 1: Understand and clean the dataset (no cleanup required here)
print("Dataset Overview:")
print(df.head())  # Display first few rows

# Step 2: Convert the categorical 'Species' column to numerical labels
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])  # Encode species

# Step 3: Split the dataset into features and target variable
X = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = df['Species']

# Step 4: Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 5: Standardize the feature data (optional for decision trees but good practice)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Step 6: Train Decision Tree Classifier using Log Loss
clf_log_loss = DecisionTreeClassifier(criterion="log_loss", max_depth=4, min_samples_split=2, random_state=42)
clf_log_loss.fit(X_train, y_train)

# Step 7: Make predictions
y_pred_log_loss = clf_log_loss.predict(X_test)

# Step 8: Evaluate the model using accuracy
def evaluate_model(y_test, y_pred):
    accuracy = accuracy_score(y_test, y_pred)
    print(f"\nAccuracy: {accuracy * 100:.2f}%")

    # Display the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    print("\nConfusion Matrix:\n", cm)

    # Print classification report
    class_report = classification_report(y_test, y_pred)
    print("\nClassification Report:\n", class_report)

    return accuracy

accuracy_log_loss = evaluate_model(y_test, y_pred_log_loss)

# Step 9: Plot the decision tree
def plot_decision_tree(clf, feature_names, class_names):
    plt.figure(figsize=(15, 10))
    plot_tree(clf, filled=True, feature_names=feature_names, class_names=class_names, rounded=True)
    plt.show()

plot_decision_tree(clf_log_loss, X.columns, le.classes_)
# Out:
# Dataset Overview:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# Accuracy: 100.00%
#
# Confusion Matrix:
#  [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# ...

# %% [markdown]
# 38.	The Iris data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.
#
# i.	Understand the Dataset & cleanup (if required).
#
# ii.	Build a logistic Regression classifier to predict the iris plant category?
#
# iii.	Evaluate the model using Accuracy.

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Iris dataset
file_path = 'Iris.csv'  # Path to the uploaded Iris dataset
df = pd.read_csv(file_path)

# Step 1: Understand and clean the dataset (no cleanup required here)
print("Dataset Overview:")
print(df.head())  # Display first few rows

# Step 2: Convert the categorical 'Species' column to numerical labels
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])  # Encode species

# Step 3: Split the dataset into features and target variable
X = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = df['Species']

# Step 4: Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 5: Standardize the feature data (optional but recommended for logistic regression)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Step 6: Train Logistic Regression classifier
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train, y_train)

# Step 7: Make predictions
y_pred = log_reg.predict(X_test)

# Step 8: Evaluate the model using accuracy
def evaluate_model(y_test, y_pred):
    accuracy = accuracy_score(y_test, y_pred)
    print(f"\nAccuracy: {accuracy * 100:.2f}%")

    # Display the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    print("\nConfusion Matrix:\n", cm)

    # Print classification report
    class_report = classification_report(y_test, y_pred)
    print("\nClassification Report:\n", class_report)

    return accuracy

accuracy_log_reg = evaluate_model(y_test, y_pred)

# Step 9: Visualize confusion matrix using seaborn heatmap
plt.figure(figsize=(8,6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Logistic Regression')
plt.show()
# Out:
# Dataset Overview:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# Accuracy: 100.00%
#
# Confusion Matrix:
#  [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# ...

# %% [markdown]
# 39.	The Iris data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.
#
# i.	Understand the Dataset & cleanup (if required).
#
# ii.	Build a Bagging Classifier model to predict the iris plant category?
#
# iii.	Evaluate the model using Accuracy.

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Iris dataset
file_path = 'Iris.csv'  # Path to the uploaded Iris dataset
df = pd.read_csv(file_path)

# Step 1: Understand and clean the dataset (no cleanup required here)
print("Dataset Overview:")
print(df.head())  # Display first few rows

# Step 2: Convert the categorical 'Species' column to numerical labels
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])  # Encode species

# Step 3: Split the dataset into features and target variable
X = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = df['Species']

# Step 4: Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 5: Standardize the feature data (optional but useful for certain models)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Step 6: Train Bagging Classifier using Decision Tree as the base model
base_model = DecisionTreeClassifier()
bagging_clf = BaggingClassifier(base_model, n_estimators=100, random_state=42)
bagging_clf.fit(X_train, y_train)

# Step 7: Make predictions
y_pred = bagging_clf.predict(X_test)

# Step 8: Evaluate the model using accuracy
def evaluate_model(y_test, y_pred):
    accuracy = accuracy_score(y_test, y_pred)
    print(f"\nAccuracy: {accuracy * 100:.2f}%")

    # Display the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    print("\nConfusion Matrix:\n", cm)

    # Print classification report
    class_report = classification_report(y_test, y_pred)
    print("\nClassification Report:\n", class_report)

    return accuracy

accuracy_bagging = evaluate_model(y_test, y_pred)

# Step 9: Visualize confusion matrix using seaborn heatmap
plt.figure(figsize=(8,6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Bagging Classifier')
plt.show()
# Out:
# Dataset Overview:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# Accuracy: 100.00%
#
# Confusion Matrix:
#  [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# ...

# %% [markdown]
# 40.	The Iris data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.
#
# i.	Understand the Dataset & cleanup (if required).
#
# ii.	Build a Random Forest Classifier model to predict the iris plant category?
#
# iii.	Evaluate the model using Accuracy.

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Iris dataset
file_path = 'Iris.csv'  # Path to the uploaded Iris dataset
df = pd.read_csv(file_path)

# Step 1: Understand and clean the dataset (no cleanup required here)
print("Dataset Overview:")
print(df.head())  # Display first few rows

# Step 2: Convert the categorical 'Species' column to numerical labels
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])  # Encode species

# Step 3: Split the dataset into features and target variable
X = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = df['Species']

# Step 4: Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 5: Standardize the feature data (optional but useful)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Step 6: Train Random Forest Classifier
rf_clf = RandomForestClassifier(n_estimators=100, random_state=42)
rf_clf.fit(X_train, y_train)

# Step 7: Make predictions
y_pred = rf_clf.predict(X_test)

# Step 8: Evaluate the model using accuracy
def evaluate_model(y_test, y_pred):
    accuracy = accuracy_score(y_test, y_pred)
    print(f"\nAccuracy: {accuracy * 100:.2f}%")

    # Display the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    print("\nConfusion Matrix:\n", cm)

    # Print classification report
    class_report = classification_report(y_test, y_pred)
    print("\nClassification Report:\n", class_report)

    return accuracy

accuracy_rf = evaluate_model(y_test, y_pred)

# Step 9: Visualize the confusion matrix using seaborn heatmap
plt.figure(figsize=(8,6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Random Forest Classifier')
plt.show()
# Out:
# Dataset Overview:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# Accuracy: 100.00%
#
# Confusion Matrix:
#  [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# ...

# %% [markdown]
# 41.	The Iris data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.
#
# i.	Understand the Dataset & cleanup (if required).
#
# ii.	Build a Gradient Boost Classifier model to predict the iris plant category?
#
# iii.	Evaluate the model using Accuracy

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Iris dataset
file_path = 'Iris.csv'  # Path to the uploaded Iris dataset
df = pd.read_csv(file_path)

# Step 1: Understand and clean the dataset (no cleanup required here)
print("Dataset Overview:")
print(df.head())  # Display first few rows

# Step 2: Convert the categorical 'Species' column to numerical labels
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])  # Encode species

# Step 3: Split the dataset into features and target variable
X = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = df['Species']

# Step 4: Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 5: Standardize the feature data (optional but useful)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Step 6: Train Gradient Boosting Classifier
gb_clf = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
gb_clf.fit(X_train, y_train)

# Step 7: Make predictions
y_pred = gb_clf.predict(X_test)

# Step 8: Evaluate the model using accuracy
def evaluate_model(y_test, y_pred):
    accuracy = accuracy_score(y_test, y_pred)
    print(f"\nAccuracy: {accuracy * 100:.2f}%")

    # Display the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    print("\nConfusion Matrix:\n", cm)

    # Print classification report
    class_report = classification_report(y_test, y_pred)
    print("\nClassification Report:\n", class_report)

    return accuracy

accuracy_gb = evaluate_model(y_test, y_pred)

# Step 9: Visualize the confusion matrix using seaborn heatmap
plt.figure(figsize=(8,6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Gradient Boosting Classifier')
plt.show()
# Out:
# Dataset Overview:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# Accuracy: 100.00%
#
# Confusion Matrix:
#  [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# ...

# %% [markdown]
# 42.	The Iris data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.
#
# i.	Understand the Dataset & cleanup (if required).
#
# ii.	Build a AdaBoost Classifier model to predict the iris plant category?
#
# iii.	Evaluate the model using Accuracy

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Iris dataset
file_path = 'Iris.csv'  # Path to the uploaded Iris dataset
df = pd.read_csv(file_path)

# Step 1: Understand and clean the dataset (no cleanup required here)
print("Dataset Overview:")
print(df.head())  # Display first few rows

# Step 2: Convert the categorical 'Species' column to numerical labels
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])  # Encode species

# Step 3: Split the dataset into features and target variable
X = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = df['Species']

# Step 4: Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 5: Standardize the feature data (optional but useful)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Step 6: Train AdaBoost Classifier
# Using DecisionTreeClassifier as a weak learner
estimator = DecisionTreeClassifier(max_depth=1, random_state=42)
ada_clf = AdaBoostClassifier(estimator=estimator, n_estimators=50, learning_rate=1.0, algorithm='SAMME', random_state=42)
ada_clf.fit(X_train, y_train)

# Step 7: Make predictions
y_pred = ada_clf.predict(X_test)

# Step 8: Evaluate the model using accuracy
def evaluate_model(y_test, y_pred):
    accuracy = accuracy_score(y_test, y_pred)
    print(f"\nAccuracy: {accuracy * 100:.2f}%")

    # Display the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    print("\nConfusion Matrix:\n", cm)

    # Print classification report
    class_report = classification_report(y_test, y_pred)
    print("\nClassification Report:\n", class_report)

    return accuracy

accuracy_ada = evaluate_model(y_test, y_pred)

# Step 9: Visualize the confusion matrix using seaborn heatmap
plt.figure(figsize=(8,6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - AdaBoost Classifier')
plt.show()
# Out:
# Dataset Overview:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# Accuracy: 100.00%
#
# Confusion Matrix:
#  [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# ...

# %% [markdown]
# 43.	The Iris data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant. Apply Principal Component Analysis on the Iris dataset.
#
# i.	Understand the Dataset & cleanup (if required).
#
# ii.	Build any one classifier of your choice on the dataset to predict the Iris plant category. (Without Applying PCA)
#
# iii.	Apply PCA technique for dimensionality reduction. And build the same classifier that you have chosen in step ii to predict the Iris plant category.  Compare the results.

# %% [markdown]
# **Step 1: Understanding the Dataset & Cleanup**
#
# ---

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Load the Iris dataset
df = pd.read_csv('Iris.csv')  # Path to your Iris dataset
print("Dataset Overview:")
print(df.head())

# Check for missing values
print("\nMissing values in each column:")
print(df.isnull().sum())

# Encode the 'Species' column to numerical labels
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])  # Encode species
# Out:
# Dataset Overview:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# Missing values in each column:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# **Step 2: Build a Classifier Without Applying PCA**

# %%
# Split the dataset into features and target variable
X = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = df['Species']

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the feature data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train a Random Forest Classifier
rf_clf = RandomForestClassifier(n_estimators=100, random_state=42)
rf_clf.fit(X_train, y_train)

# Make predictions
y_pred = rf_clf.predict(X_test)

# Evaluate the model
print("Without PCA:")
print(f"Accuracy: {accuracy_score(y_test, y_pred) * 100:.2f}%")
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Without PCA:
# Accuracy: 100.00%
# Confusion Matrix:
#  [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# **Step 3: Apply PCA for Dimensionality Reduction**

# %%
# Step 1: Standardize the data again
X_scaled = scaler.fit_transform(X)

# Step 2: Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Step 3: Split the PCA-transformed dataset into training and testing sets
X_train_pca, X_test_pca, y_train, y_test = train_test_split(X_pca, y, test_size=0.3, random_state=42)

# Step 4: Train the same classifier on PCA-reduced data
rf_clf_pca = RandomForestClassifier(n_estimators=100, random_state=42)
rf_clf_pca.fit(X_train_pca, y_train)

# Step 5: Make predictions
y_pred_pca = rf_clf_pca.predict(X_test_pca)

# Evaluate the model
print("With PCA:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_pca) * 100:.2f}%")
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_pca))
print("\nClassification Report:\n", classification_report(y_test, y_pred_pca))

# Step 6: Explained variance ratio
print(f"\nExplained Variance Ratios: {pca.explained_variance_ratio_}")

# Step 7: Scatterplot of the PCA result
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis', edgecolor='k', s=40)
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.title('PCA on Iris Dataset (4 dimensions reduced to 2)')
plt.show()
# Out:
# With PCA:
# Accuracy: 95.56%
# Confusion Matrix:
#  [[19  0  0]
#  [ 0 12  1]
#  [ 0  1 12]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       0.92      0.92      0.92        13
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45
#
#
# Explained Variance Ratios: [0.72770452 0.23030523]
